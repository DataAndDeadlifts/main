# %% [raw]
# ---
# description: 1. Reference Genome Sequence (fasta)
# output-file: 00 data.html
# title: Getting data from NCBI
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(load_config)
# Out:
# ---
#
# ### load_config
#
# >      load_config (path:pathlib.Path=Path('../config.yml'))

# %%
#| echo: false
#| output: asis
show_doc(download_data)
# Out:
# ---
#
# ### download_data
#
# >      download_data (data_path:pathlib.Path)
