# %% [raw]
# ---
# description: '"This code builds training data for our LLM."'
# output-file: make-genome-training-data.html
# title: features.genome
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
import gzip
from pathlib import Path

# %%
#| echo: false
#| output: asis
show_doc(get_genome_file_pointer)
# Out:
# ---
#
# ### get_genome_file_pointer
#
# >      get_genome_file_pointer (path)

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/DataAndDeadlifts/llm-mito-scanner/blob/main/llm_mito_scanner/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()

# %%
# !nbdev_clean
